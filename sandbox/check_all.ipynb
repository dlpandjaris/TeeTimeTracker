# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
from datetime import datetime
import pytz

# %%
sw_lat, sw_long = 38.757, -94.908
ne_lat, ne_long = 39.427, -94.235
query = f"""
[out:json];
(
  node["leisure"="golf_course"]({sw_lat}, {sw_long}, {ne_lat}, {ne_long});
  way["leisure"="golf_course"]({sw_lat}, {sw_long}, {ne_lat}, {ne_long});
  relation["leisure"="golf_course"]({sw_lat}, {sw_long}, {ne_lat}, {ne_long});
);
out center;
"""

response = requests.post("https://overpass-api.de/api/interpreter", data={"data": query})
data = response.json()
for el in data["elements"]:
  name = el.get("tags", {}).get("name")
  lat = el.get("lat")
  lon = el.get("lon")
  if lat == None:
    lat = el.get("center", {}).get("lat")
  if lon == None:
    lon = el.get("center", {}).get("lon")
  if name != None:
    print(f'{name}: {lat}, {lon}')
  # print(el)
# Out:
# Posse Course: 39.4213658, -94.5476547
# The Hill Course: 38.986333, -94.5238809
# The Rock Course: 38.9893881, -94.5222873
# The River Course: 38.9919431, -94.5278009
# Paradise Pointe: 39.4232906, -94.5514754
# Brough Creek National GC: 39.1671392, -94.7610853
# Smiley's Golf Complex: 38.9440764, -94.8480508
# Overland Park Golf Course: 38.90372, -94.7189616
# Westlinks Golf Course: 38.8926212, -94.7335267
# Swope Memorial Golf Course: 38.9988071, -94.5131265
# Heart of America Golf Course: 38.991176, -94.5260483
# St Andrews Golf Club: 38.8787932, -94.7118029
# Lake Quivira Country Club: 39.0455078, -94.7657634
# Milburn Country Club: 39.0040805, -94.6767136
# Tomahawk Hills Golf Course: 38.9971895, -94.7900334
# Royal Meadows Golf Club: 39.0336354, -94.4583346
# The Kansas City Country Club: 39.0215514, -94.6208824
# Sycamore Ridge Golf Club: 38.7565789, -94.840674
# Wolf Creek Golf: 38.7927887, -94.7537362
# Driving Range: 39.2654783, -94.5128536
# Hodge Park Golf Course: 39.2532934, -94.4939931
# Shoal Creek Golf Course: 39.2528261, -94.4788154
# Leavenworth Golf Club (CLOSED): 39.2644117, -94.9046453
# Ironhorse Golf Club: 38.8509525, -94.6350275
# Heritage Park Golf Course: 38.8273693, -94.7550834
# Cardinal Hill Golf Course: 39.262035, -94.4071598
# Paradise Point Golf Course: 39.4256056, -94.5464477
# Hillcrest Golf & Country Club: 38.9802582, -94.5252091
# Indian Hills Country Club: 39.0029916, -94.6230982
# Mission Hills Country Club: 39.0291282, -94.6120171
# Blue Hills Country Club: 38.8979281, -94.5993411
# Eagles' Landing Golf Course: 38.8357479, -94.5514032
# Oakwood Country Club: 38.9442973, -94.5532728
# Minor Park Golf Course: 38.9218788, -94.5789712
# Drumm Farm Golf Club: 39.0620829, -94.3981964
# Sunflower Hills Golf Course: 39.1037935, -94.8676643
# Winterstone Golf Course: 39.1250818, -94.3787228
# Shiloh Springs Golf Course: 39.3617378, -94.7280011
# Adams Pointe Golf Course: 39.019879, -94.2414334
# MariMack Golf Complex: 39.371535, -94.3503011
# Falcon Lakes Golf Club: 39.1650906, -94.9107302
# Dub's Dread Golf Club: 39.1685497, -94.8752899
# Teetering Rocks Golf Course: 38.9628262, -94.4396519
# Fred Arbanas Golf Course: 38.9186516, -94.456896
# Par 3 course: 38.9222203, -94.4539399
# The Unity Village Golf Course: 38.9536138, -94.4054117
# Lake of the Forest Golf Course: 39.0690382, -94.8319121
# Posse: 39.4230916, -94.5472098
# Shamrock Hills Golf Club: 38.8635434, -94.3665596
# Falcon Lakes Golf Club: 39.1650505, -94.910161
# Tiffany Greens Golf Club: 39.2804914, -94.6433335
# Sykes/Lady Overland Park Golf Complex: 38.8981327, -94.7259369
# Staley Farms Golf Club: 39.2818563, -94.5455377
# The Deuce at the National: 39.2057349, -94.6991987
# The Duece at the National: 39.2135906, -94.7021915
# The National Golf Club: 39.2197518, -94.7097866
# Falcon Ridge Golf Course: 38.9542992, -94.8245417
# Creekmoor Golf Club: 38.8334137, -94.4689148
# Grand Summit Golf & Country Club: 38.8500334, -94.5148175
# Country Club of Leawood: 38.8985634, -94.6200496
# Deer Creek Golf Club: 38.8921486, -94.660734
# Nicklaus Golf Club at LionsGate: 38.8752099, -94.6561277
# Lakewood Oaks Golf Club: 39.0063027, -94.3637894
# Stone Canyon Golf Club: 39.0427869, -94.3179918
# Country Club at Loch Lloyd: 38.8349045, -94.5953927
# Country Club Gardens: 39.0346067, -94.2628347
# Painted Hills Golf Club: 39.1242683, -94.7417212
# Shawnee Golf Course & Country Club: 39.0107826, -94.8633368
# Shadow Glen Golf Club: 38.9366702, -94.8948041
# Prairie Highlands Golf Course: 38.8617819, -94.8832094
# Hallbrook Country Club: 38.9220061, -94.6175308
# Canyon Farms Golf Club: 38.9641577, -94.7908632

# %%
class GolfCourse:
  def __init__(self, id, name, lat, lon, source):
    self.id = id
    self.name = name
    self.lat = lat
    self.lon = lon
    self.source = source

  def to_dict(self):
    return {
      "id": self.id,
      "name": self.name,
      "lat": self.lat,
      "lon": self.lon,
      "source": self.source
    }

  def __repr__(self):
    return f"GolfCourse(name={self.name}, lat={self.lat}, lon={self.lon}), source={self.source})"

# %%
# Coordinates you posted — cleaned into a dictionary
coordinates = {
  'Shoal Creek Golf Course': (39.2528261, -94.4788154),
  'Hodge Park Golf Course': (39.2532934, -94.4939931),
  'Winterstone Golf Course': (39.1250818, -94.3787228),
  'Adams Pointe Golf Course': (39.019879, -94.2414334),
  'Heart of America Golf Course': (38.991176, -94.5260483),
  'Sycamore Ridge Golf Club': (38.7565789, -94.840674),
  'Paradise Pointe Golf Course - The Outlaw': (39.4232906, -94.5514754),  # Using Paradise Pointe
  'Paradise Pointe Golf Course - The Posse': (39.4230916, -94.5472098),  # Posse
  'Falcon Lakes Golf Club': (39.1650505, -94.910161),
  "Dub's Dread Golf Club": (39.1685497, -94.8752899),
  'Painted Hills Golf Club': (39.1242683, -94.7417212),
  'Drumm Farm Golf Club - Full': (39.0620829, -94.3981964),
  'Drumm Farm Golf Club - Executive': (39.0620829, -94.3981964),  # Same coords
  'Royal Meadows Golf Club': (39.0336354, -94.4583346),
  'Teetering Rocks Golf Course': (38.9628262, -94.4396519),
  'Heritage Park Golf Course': (38.8273693, -94.7550834),
  'Tomahawk Hills Golf Course': (38.9971895, -94.7900334),
  'Sunflower Hills Golf Course': (39.1037935, -94.8676643),
}

# %%
bookateetime_courses = {
  'Shoal Creek Golf Course': '118-1',
  'Hodge Park Golf Course': '117-1',
  'Winterstone Golf Course': '62-1',
  'Adams Pointe Golf Course': '45-1',
  'Heart of America Golf Course': '49-1',
  'Sycamore Ridge Golf Club': '44-1',
  'Paradise Pointe Golf Course - The Outlaw': '24-1',
  'Paradise Pointe Golf Course - The Posse': '24-2',
}

chronogolf_courses = {
  'Falcon Lakes Golf Club': 6633,
}

golfback_courses = {
  "Dub's Dread Golf Club": '398d44ce-a908-4ce7-8f50-e5f4bdc77b73',
  'Painted Hills Golf Club': '857a12d4-a9cf-4a43-afe2-60940bdc7438',
  'Drumm Farm Golf Club - Full': 'd70999c9-d7d4-4008-9f41-4e9551b3c796',
  'Drumm Farm Golf Club - Executive': '9a1de435-8a46-4840-9cdc-332c3cfea782',
  'Royal Meadows Golf Club': 'd2278228-4700-4354-95a8-422a8f9a5a16'
}

foreup_courses = {
  'Teetering Rocks Golf Course': 7341,
  'Heritage Park Golf Course': 12159,
  'Tomahawk Hills Golf Course': 11026,
}

loners = {
  'Sunflower Hills Golf Course': 'https://www.sunflowerhillsgolfcourse.com/TeeTimes',
}

# %%
courses = []

# Helper to add courses
def add_courses(source_name, courses_dict):
  for name, id in courses_dict.items():
    coord = coordinates.get(name)
    if coord:
      lat, lon = coord
      courses.append(GolfCourse(id=id, name=name, lat=lat, lon=lon, source=source_name))
    else:
      print(f"[Warning] No coordinates found for: {name}")

add_courses('bookateetime', bookateetime_courses)
add_courses('chronogolf', chronogolf_courses)
add_courses('golfback', golfback_courses)
add_courses('foreup', foreup_courses)
add_courses('loner', loners)

# %%
for course in courses:
  print(course)
# Out:
# GolfCourse(name=Shoal Creek Golf Course, lat=39.2528261, lon=-94.4788154), source=bookateetime)
# GolfCourse(name=Hodge Park Golf Course, lat=39.2532934, lon=-94.4939931), source=bookateetime)
# GolfCourse(name=Winterstone Golf Course, lat=39.1250818, lon=-94.3787228), source=bookateetime)
# GolfCourse(name=Adams Pointe Golf Course, lat=39.019879, lon=-94.2414334), source=bookateetime)
# GolfCourse(name=Heart of America Golf Course, lat=38.991176, lon=-94.5260483), source=bookateetime)
# GolfCourse(name=Sycamore Ridge Golf Club, lat=38.7565789, lon=-94.840674), source=bookateetime)
# GolfCourse(name=Paradise Pointe Golf Course - The Outlaw, lat=39.4232906, lon=-94.5514754), source=bookateetime)
# GolfCourse(name=Paradise Pointe Golf Course - The Posse, lat=39.4230916, lon=-94.5472098), source=bookateetime)
# GolfCourse(name=Falcon Lakes Golf Club, lat=39.1650505, lon=-94.910161), source=chronogolf)
# GolfCourse(name=Dub's Dread Golf Club, lat=39.1685497, lon=-94.8752899), source=golfback)
# GolfCourse(name=Painted Hills Golf Club, lat=39.1242683, lon=-94.7417212), source=golfback)
# GolfCourse(name=Drumm Farm Golf Club - Full, lat=39.0620829, lon=-94.3981964), source=golfback)
# GolfCourse(name=Drumm Farm Golf Club - Executive, lat=39.0620829, lon=-94.3981964), source=golfback)
# GolfCourse(name=Royal Meadows Golf Club, lat=39.0336354, lon=-94.4583346), source=golfback)
# GolfCourse(name=Teetering Rocks Golf Course, lat=38.9628262, lon=-94.4396519), source=foreup)
# GolfCourse(name=Heritage Park Golf Course, lat=38.8273693, lon=-94.7550834), source=foreup)
# GolfCourse(name=Tomahawk Hills Golf Course, lat=38.9971895, lon=-94.7900334), source=foreup)
# GolfCourse(name=Sunflower Hills Golf Course, lat=39.1037935, lon=-94.8676643), source=loner)

# %%
courses[-3].id
# Out:
# 12159

# %%
import json

# Convert to list of dicts
courses_json = [course.to_dict() for course in courses]

# Option 1: Write to local file
with open('../golf_courses.json', 'w') as f:
    json.dump(courses_json, f, indent=2)

print("Saved to golf_courses.json ✅")
# Out:
# Saved to golf_courses.json ✅

# %%
with open('../golf_courses.json', 'r') as f:
  courses_data = json.load(f)

courses = [GolfCourse(**course) for course in courses_data]

# %%
date = '2025-05-02'
players = 4

tee_times_df = pd.DataFrame()

for course in courses:
  if course.source == 'bookateetime':
    # Make a GET request to the URL with the course name and date
    response = requests.get(f"https://bookateetime.teequest.com/search/{course.id}/{date}?selectedPlayers={players}&selectedHoles=18")

    # Decode the response content as a string
    content_str = response.content.decode('utf-8')
    soup = BeautifulSoup(content_str, 'html.parser')
    tee_times = []

    for tee_time_div in soup.find_all('div', class_='tee-time'):
      href = tee_time_div.find('a', class_='btn')['href']
      tt = {
        'course': course.name,
        'tee_time': pd.to_datetime(tee_time_div['data-date-time'], format='%Y%m%d%H%M'), #tee_time_div['data-date-time'],
        'price': float(tee_time_div['data-price']),
        'players': int(tee_time_div['data-available']),
        'lat': course.lat,
        'lon': course.lon,
        'book_url': f'https://bookateetime.teequest.com{href}'
      }
      tee_times.append(tt)

    tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)

  if course.source == 'golfback':
    url = f"https://api.golfback.com/api/v1/courses/{course.id}/date/{date}/teetimes"
    headers = {
      "User-Agent": "Mozilla/5.0",
      "Referer": "https://golfback.com/",
      "Content-Type": "application/json",
    }
    params = {
      "date": date,
      "course_id": course.id,
      "players": players
    }

    response = requests.post(url, headers=headers, json=params)
    tee_times_raw = response.json()['data']
    
    tee_times = []
    for tee_time in tee_times_raw:
      tt = {
        'course': course.name,
        'tee_time': pd.to_datetime(tee_time['dateTime'], format='%Y-%m-%dT%H:%M:%S%z') \
          .astimezone(pytz.timezone("US/Central")).strftime("%Y-%m-%d %H:%M:%S"),
        'price': float(tee_time['rates'][0]['price']),
        'players': tee_time['playersMax'],
        'lat': course.lat,
        'lon': course.lon,
        'book_url': f'https://golfback.com/#/course/{course.id}/date/{date}/teetime/{tee_time['id']}?rateId={tee_time['rates'][0]['ratePlanId']}&holes=18&players={players}'
      }
      tee_times.append(tt)

    tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)
  
  if course.source == 'foreup':
    flip_date = datetime.strptime(date, '%Y-%m-%d').strftime('%m-%d-%Y')
    url = f"https://foreupsoftware.com/index.php/api/booking/times?time=all&date={flip_date}&holes=all&players={players}&booking_class=14824&schedule_id={course.id}&api_key=no_limits"
    headers = {
      "User-Agent": "Mozilla/5.0",
      "Referer": f"https://foreupsoftware.com/index.php/booking/22857/7340",
      "Content-Type": "application/json",
    }
    params = {
      "date": datetime.strptime(date, '%Y-%m-%d').strftime('%m-%d-%Y'),
      "players": players,
    }

    response = requests.get(url, headers=headers, json=params)
    tee_times_raw = response.json()

    tee_times = []
    for tee_time in tee_times_raw:
      # print(tee_time)
      # break
      tt = {
        'course': course.name,
        'tee_time': pd.to_datetime(tee_time['time'], format='%Y-%m-%d %H:%M'),
        'price': float(tee_time['green_fee'] + tee_time['cart_fee']),
        'players': tee_time['available_spots'],
        'lat': course.lat,
        'lon': course.lon,
        'book_url': f'https://foreupsoftware.com/index.php/booking/22857/{course.id}#/teetimes'
      }
      tee_times.append(tt)

    tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)

# %%
tee_times_df
# Out:
#                          course             tee_time  price  players  \
# 0       Shoal Creek Golf Course  2025-05-02 16:20:00   50.0        4
# 1       Shoal Creek Golf Course  2025-05-02 16:30:00   50.0        4
# 2       Shoal Creek Golf Course  2025-05-02 16:40:00   50.0        4
# 3       Shoal Creek Golf Course  2025-05-02 16:50:00   50.0        4
# 4       Shoal Creek Golf Course  2025-05-02 17:00:00   50.0        4
# ..                          ...                  ...    ...      ...
# 430   Heritage Park Golf Course  2025-05-02 07:30:00   48.0        4
# 431  Tomahawk Hills Golf Course  2025-05-02 16:10:00   31.0        4
# 432  Tomahawk Hills Golf Course  2025-05-02 16:20:00   31.0        4
# 433  Tomahawk Hills Golf Course  2025-05-02 16:40:00   31.0        4
# 434  Tomahawk Hills Golf Course  2025-05-02 17:20:00   31.0        4
#
#            lat        lon                                           book_url
# 0    39.252826 -94.478815  https://bookateetime.teequest.com/teetime/118-...
# 1    39.252826 -94.478815  https://bookateetime.teequest.com/teetime/118-...
# 2    39.252826 -94.478815  https://bookateetime.teequest.com/teetime/118-...
# 3    39.252826 -94.478815  https://bookateetime.teequest.com/teetime/118-...
# 4    39.252826 -94.478815  https://bookateetime.teequest.com/teetime/118-...
# ..         ...        ...                                                ...
# 430  38.827369 -94.755083                                                NaN
# 431  38.997189 -94.790033                                                NaN
# 432  38.997189 -94.790033                                                NaN
# 433  38.997189 -94.790033                                                NaN
# 434  38.997189 -94.790033                                                NaN
#
# [435 rows x 7 columns]

# %%
date = '2025-05-02'
players = 4

tee_times_df = pd.DataFrame()

for course in bookateetime_courses.items():
  # Make a GET request to the URL with the course name and date
  response = requests.get(f"https://bookateetime.teequest.com/search/{course[1]}/{date}?selectedPlayers={players}&selectedHoles=18")

  # Decode the response content as a string
  content_str = response.content.decode('utf-8')
  soup = BeautifulSoup(content_str, 'html.parser')
  tee_times = []

  for tee_time_div in soup.find_all('div', class_='tee-time'):
    href = tee_time_div.find('a', class_='btn')['href']
    tt = {
      'course': course[0],
      'tee_time': pd.to_datetime(tee_time_div['data-date-time'], format='%Y%m%d%H%M'), #tee_time_div['data-date-time'],
      'price': float(tee_time_div['data-price']),
      'players': int(tee_time_div['data-available']),
      'book_url': f'https://bookateetime.teequest.com{href}'
    }
    tee_times.append(tt)

  tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)

# Convert the 'date_time' column to datetime format
# tee_times_df['tee_time'] = pd.to_datetime(tee_times_df['tee_time'], format='%Y%m%d%H%M')

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.max_colwidth', None) # Show full column content

tee_times_df[
  tee_times_df['course'] == 'Paradise Pointe Golf Course - The Posse'
].sort_values('tee_time').head(10)
# Out:
#                                       course            tee_time  price  \
# 105  Paradise Pointe Golf Course - The Posse 2025-05-02 08:30:00   46.0
# 106  Paradise Pointe Golf Course - The Posse 2025-05-02 12:50:00   61.0
# 107  Paradise Pointe Golf Course - The Posse 2025-05-02 13:20:00   61.0
# 108  Paradise Pointe Golf Course - The Posse 2025-05-02 13:40:00   61.0
# 109  Paradise Pointe Golf Course - The Posse 2025-05-02 13:50:00   61.0
# 110  Paradise Pointe Golf Course - The Posse 2025-05-02 14:00:00   61.0
# 111  Paradise Pointe Golf Course - The Posse 2025-05-02 14:10:00   61.0
# 112  Paradise Pointe Golf Course - The Posse 2025-05-02 14:20:00   61.0
# 113  Paradise Pointe Golf Course - The Posse 2025-05-02 14:30:00   61.0
# 114  Paradise Pointe Golf Course - The Posse 2025-05-02 14:40:00   61.0
#
#      players  \
# 105        4
# 106        4
# 107        4
# 108        4
# 109        4
# 110        4
# 111        4
# 112        4
# 113        4
# 114        4
#
#                                                                     book_url
# 105  https://bookateetime.teequest.com/teetime/24-2/202505020830/1/A/CS/4/18
# 106  https://bookateetime.teequest.com/teetime/24-2/202505021250/1/A/AO/4/18
# 107  https://bookateetime.teequest.com/teetime/24-2/202505021320/1/A/AO/4/18
# 108  https://bookateetime.teequest.com/teetime/24-2/202505021340/1/A/AO/4/18
# 109  https://bookateetime.teequest.com/teetime/24-2/202505021350/1/A/AO/4/18
# 110  https://bookateetime.teequest.com/teetime/24-2/202505021400/1/A/AO/4/18
# 111  https://bookateetime.teequest.com/teetime/24-2/202505021410/1/A/AO/4/18
# 112  https://bookateetime.teequest.com/teetime/24-2/202505021420/1/A/AO/4/18
# 113  https://bookateetime.teequest.com/teetime/24-2/202505021430/1/A/AO/4/18
# 114  https://bookateetime.teequest.com/teetime/24-2/202505021440/1/A/AO/4/18

# %%
for course in golfback_courses.items():
  url = f"https://api.golfback.com/api/v1/courses/{course[1]}/date/{date}/teetimes"
  headers = {
    "User-Agent": "Mozilla/5.0",
    "Referer": "https://golfback.com/",
    "Content-Type": "application/json",
  }
  params = {
    "date": date,
    "course_id": course[1],
    "players": players
  }

  response = requests.post(url, headers=headers, json=params)
  tee_times_raw = response.json()['data']
  
  tee_times = []
  for tee_time in tee_times_raw:
    tt = {
      'course': course[0],
      'tee_time': pd.to_datetime(tee_time['dateTime'], format='%Y-%m-%dT%H:%M:%S%z') \
        .astimezone(pytz.timezone("US/Central")).strftime("%Y-%m-%d %H:%M:%S"),
      'price': float(tee_time['rates'][0]['price']),
      'players': tee_time['playersMax'],
      'book_url': f'https://golfback.com/#/course/{course[1]}/date/{date}/teetime/{tee_time['id']}?rateId={tee_time['rates'][0]['ratePlanId']}&holes=18&players={players}'
    }
    tee_times.append(tt)

  tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)

# %%
for course in foreup_courses.items():
  flip_date = datetime.strptime(date, '%Y-%m-%d').strftime('%m-%d-%Y')
  url = f"https://foreupsoftware.com/index.php/api/booking/times?time=all&date={flip_date}&holes=all&players={players}&booking_class=14824&schedule_id={course[1]}&api_key=no_limits"
  headers = {
    "User-Agent": "Mozilla/5.0",
    "Referer": f"https://foreupsoftware.com/index.php/booking/22857/7340",
    "Content-Type": "application/json",
  }
  params = {
    "date": datetime.strptime(date, '%Y-%m-%d').strftime('%m-%d-%Y'),
    "players": players,
  }

  response = requests.get(url, headers=headers, json=params)
  tee_times_raw = response.json()

  tee_times = []
  for tee_time in tee_times_raw:
    # print(tee_time)
    # break
    tt = {
      'course': course[0],
      'tee_time': pd.to_datetime(tee_time['time'], format='%Y-%m-%d %H:%M'),
      'price': float(tee_time['green_fee'] + tee_time['cart_fee']),
      'players': tee_time['available_spots']
    }
    tee_times.append(tt)

  tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)

# %%
tee_times_df.head()
# Out:
#                     course             tee_time  price  players  \
# 0  Shoal Creek Golf Course  2025-05-02 16:20:00   50.0        4
# 1  Shoal Creek Golf Course  2025-05-02 16:30:00   50.0        4
# 2  Shoal Creek Golf Course  2025-05-02 16:40:00   50.0        4
# 3  Shoal Creek Golf Course  2025-05-02 16:50:00   50.0        4
# 4  Shoal Creek Golf Course  2025-05-02 17:00:00   50.0        4
#
#                                                                    book_url
# 0  https://bookateetime.teequest.com/teetime/118-1/202505021620/1/A/CS/4/18
# 1  https://bookateetime.teequest.com/teetime/118-1/202505021630/1/A/CS/4/18
# 2  https://bookateetime.teequest.com/teetime/118-1/202505021640/1/A/CS/4/18
# 3  https://bookateetime.teequest.com/teetime/118-1/202505021650/1/A/CS/4/18
# 4  https://bookateetime.teequest.com/teetime/118-1/202505021700/1/A/CS/4/18

# %%
tee_times_df['tee_time'] = pd.to_datetime(tee_times_df['tee_time'], utc=True)

# %%
tee_times_df.head()
# Out:
#                     course                  tee_time  price  players  \
# 0  Shoal Creek Golf Course 2025-05-02 16:20:00+00:00   50.0        4
# 1  Shoal Creek Golf Course 2025-05-02 16:30:00+00:00   50.0        4
# 2  Shoal Creek Golf Course 2025-05-02 16:40:00+00:00   50.0        4
# 3  Shoal Creek Golf Course 2025-05-02 16:50:00+00:00   50.0        4
# 4  Shoal Creek Golf Course 2025-05-02 17:00:00+00:00   50.0        4
#
#                                                                    book_url
# 0  https://bookateetime.teequest.com/teetime/118-1/202505021620/1/A/CS/4/18
# 1  https://bookateetime.teequest.com/teetime/118-1/202505021630/1/A/CS/4/18
# 2  https://bookateetime.teequest.com/teetime/118-1/202505021640/1/A/CS/4/18
# 3  https://bookateetime.teequest.com/teetime/118-1/202505021650/1/A/CS/4/18
# 4  https://bookateetime.teequest.com/teetime/118-1/202505021700/1/A/CS/4/18

# %%
tee_times_df[
  (tee_times_df['tee_time'].dt.hour >= 16) &
  (tee_times_df['price'] <= 90)
].sort_values(by=['course', 'tee_time']).head()#.to_csv('tee_times.csv', index=False)
# Out:
#                       course                  tee_time  price  players  \
# 68  Adams Pointe Golf Course 2025-05-02 16:09:00+00:00   45.0        4
# 69  Adams Pointe Golf Course 2025-05-02 16:18:00+00:00   45.0        4
# 70  Adams Pointe Golf Course 2025-05-02 16:27:00+00:00   45.0        4
# 71  Adams Pointe Golf Course 2025-05-02 16:36:00+00:00   45.0        4
# 72  Adams Pointe Golf Course 2025-05-02 16:45:00+00:00   45.0        4
#
#                                                                    book_url
# 68  https://bookateetime.teequest.com/teetime/45-1/202505021609/1/A/AO/4/18
# 69  https://bookateetime.teequest.com/teetime/45-1/202505021618/1/A/AO/4/18
# 70  https://bookateetime.teequest.com/teetime/45-1/202505021627/1/A/AO/4/18
# 71  https://bookateetime.teequest.com/teetime/45-1/202505021636/1/A/AO/4/18
# 72  https://bookateetime.teequest.com/teetime/45-1/202505021645/1/A/AO/4/18

# %%
tee_times_df.sort_values(by=['course', 'tee_time']).to_csv('tee_times.csv', index=False)

# %%
response = requests.get('https://tee-time-service-1091750267004.us-central1.run.app/tee_times?date=2025-05-03&players=4')

# %%
response.json()
# Out:
# [{'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031620/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 16:20:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031630/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 16:30:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031640/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 16:40:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031650/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 16:50:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031700/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 17:00:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031710/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 17:10:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031720/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 17:20:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031730/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 17:30:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031740/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 17:40:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031750/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 17:50:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031800/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 18:00:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031810/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 18:10:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031820/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 18:20:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031830/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 18:30:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031840/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 18:40:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031850/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 18:50:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/118-1/202505031900/1/A/CS/4/18',
#   'course': 'Shoal Creek Golf Course',
#   'lat': 39.2528261,
#   'lon': -94.4788154,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 19:00:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031518/1/A/CS/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 35.0,
#   'tee_time': 'Sat, 03 May 2025 15:18:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031545/1/A/CS/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 35.0,
#   'tee_time': 'Sat, 03 May 2025 15:45:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031554/1/A/CS/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 35.0,
#   'tee_time': 'Sat, 03 May 2025 15:54:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031603/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 16:03:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031612/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 16:12:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031621/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 16:21:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031630/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 16:30:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031639/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 16:39:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031648/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 16:48:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031657/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 16:57:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031715/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 17:15:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031724/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 17:24:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031733/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 17:33:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031742/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 17:42:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031751/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 17:51:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/117-1/202505031800/1/A/AO/4/18',
#   'course': 'Hodge Park Golf Course',
#   'lat': 39.2532934,
#   'lon': -94.4939931,
#   'players': 4,
#   'price': 42.0,
#   'tee_time': 'Sat, 03 May 2025 18:00:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/62-1/202505031536/1/A/CS/4/18',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 15:36:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/62-1/202505031545/1/A/CS/4/18',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 15:45:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/62-1/202505031554/1/A/CS/4/18',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 15:54:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/62-1/202505031603/1/A/CS/4/18',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 16:03:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/62-1/202505031612/1/A/CS/4/18',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 16:12:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/62-1/202505031621/1/A/CS/4/18',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 16:21:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/62-1/202505031630/1/A/CS/4/18',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 16:30:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/62-1/202505031639/1/A/CS/4/18',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 16:39:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/62-1/202505031648/1/A/CS/4/18',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 16:48:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/62-1/202505031657/1/A/CS/4/18',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 16:57:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 17:06:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 17:15:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 17:24:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 17:33:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 17:42:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 17:51:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 18:00:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 18:09:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 18:18:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 18:27:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 18:36:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 18:45:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 18:54:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 19:03:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 19:12:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 19:21:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 19:30:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 19:39:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 19:48:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.comtel:8162575755',
#   'course': 'Winterstone Golf Course',
#   'lat': 39.1250818,
#   'lon': -94.3787228,
#   'players': 4,
#   'price': 45.0,
#   'tee_time': 'Sat, 03 May 2025 19:57:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031636/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 16:36:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031645/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 16:45:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031654/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 50.0,
#   'tee_time': 'Sat, 03 May 2025 16:54:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031703/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 17:03:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031712/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 17:12:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031721/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 17:21:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031730/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 17:30:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031739/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 17:39:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031748/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 17:48:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031757/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 17:57:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031806/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 18:06:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031815/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 18:15:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031824/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 18:24:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031833/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 18:33:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031842/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 18:42:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031851/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 18:51:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/45-1/202505031900/1/A/AO/4/18',
#   'course': 'Adams Pointe Golf Course',
#   'lat': 39.019879,
#   'lon': -94.2414334,
#   'players': 4,
#   'price': 40.0,
#   'tee_time': 'Sat, 03 May 2025 19:00:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/44-1/202505031650/1/A/CS/4/18',
#   'course': 'Sycamore Ridge Golf Club',
#   'lat': 38.7565789,
#   'lon': -94.840674,
#   'players': 4,
#   'price': 35.0,
#   'tee_time': 'Sat, 03 May 2025 16:50:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/44-1/202505031700/1/A/CS/4/18',
#   'course': 'Sycamore Ridge Golf Club',
#   'lat': 38.7565789,
#   'lon': -94.840674,
#   'players': 4,
#   'price': 35.0,
#   'tee_time': 'Sat, 03 May 2025 17:00:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/44-1/202505031720/1/A/CS/4/18',
#   'course': 'Sycamore Ridge Golf Club',
#   'lat': 38.7565789,
#   'lon': -94.840674,
#   'players': 4,
#   'price': 35.0,
#   'tee_time': 'Sat, 03 May 2025 17:20:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/44-1/202505031730/1/A/CS/4/18',
#   'course': 'Sycamore Ridge Golf Club',
#   'lat': 38.7565789,
#   'lon': -94.840674,
#   'players': 4,
#   'price': 35.0,
#   'tee_time': 'Sat, 03 May 2025 17:30:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/44-1/202505031740/1/A/CS/4/18',
#   'course': 'Sycamore Ridge Golf Club',
#   'lat': 38.7565789,
#   'lon': -94.840674,
#   'players': 4,
#   'price': 35.0,
#   'tee_time': 'Sat, 03 May 2025 17:40:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/44-1/202505031750/1/A/CS/4/18',
#   'course': 'Sycamore Ridge Golf Club',
#   'lat': 38.7565789,
#   'lon': -94.840674,
#   'players': 4,
#   'price': 35.0,
#   'tee_time': 'Sat, 03 May 2025 17:50:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-1/202505031340/1/A/CS/4/18',
#   'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'lat': 39.4232906,
#   'lon': -94.5514754,
#   'players': 4,
#   'price': 48.0,
#   'tee_time': 'Sat, 03 May 2025 13:40:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-1/202505031350/1/A/AO/4/18',
#   'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'lat': 39.4232906,
#   'lon': -94.5514754,
#   'players': 4,
#   'price': 64.0,
#   'tee_time': 'Sat, 03 May 2025 13:50:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-1/202505031410/1/A/CS/4/18',
#   'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'lat': 39.4232906,
#   'lon': -94.5514754,
#   'players': 4,
#   'price': 48.0,
#   'tee_time': 'Sat, 03 May 2025 14:10:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-1/202505031420/1/A/AO/4/18',
#   'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'lat': 39.4232906,
#   'lon': -94.5514754,
#   'players': 4,
#   'price': 64.0,
#   'tee_time': 'Sat, 03 May 2025 14:20:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-1/202505031430/1/A/AO/4/18',
#   'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'lat': 39.4232906,
#   'lon': -94.5514754,
#   'players': 4,
#   'price': 64.0,
#   'tee_time': 'Sat, 03 May 2025 14:30:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-1/202505031440/1/A/CS/4/18',
#   'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'lat': 39.4232906,
#   'lon': -94.5514754,
#   'players': 4,
#   'price': 48.0,
#   'tee_time': 'Sat, 03 May 2025 14:40:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-1/202505031450/1/A/AO/4/18',
#   'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'lat': 39.4232906,
#   'lon': -94.5514754,
#   'players': 4,
#   'price': 64.0,
#   'tee_time': 'Sat, 03 May 2025 14:50:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-1/202505031510/1/A/AO/4/18',
#   'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'lat': 39.4232906,
#   'lon': -94.5514754,
#   'players': 4,
#   'price': 64.0,
#   'tee_time': 'Sat, 03 May 2025 15:10:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-1/202505031520/1/A/AO/4/18',
#   'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'lat': 39.4232906,
#   'lon': -94.5514754,
#   'players': 4,
#   'price': 64.0,
#   'tee_time': 'Sat, 03 May 2025 15:20:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-1/202505031530/1/A/AO/4/18',
#   'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'lat': 39.4232906,
#   'lon': -94.5514754,
#   'players': 4,
#   'price': 64.0,
#   'tee_time': 'Sat, 03 May 2025 15:30:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-2/202505031500/1/A/AO/4/18',
#   'course': 'Paradise Pointe Golf Course - The Posse',
#   'lat': 39.4230916,
#   'lon': -94.5472098,
#   'players': 4,
#   'price': 64.0,
#   'tee_time': 'Sat, 03 May 2025 15:00:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-2/202505031540/1/A/AO/4/18',
#   'course': 'Paradise Pointe Golf Course - The Posse',
#   'lat': 39.4230916,
#   'lon': -94.5472098,
#   'players': 4,
#   'price': 64.0,
#   'tee_time': 'Sat, 03 May 2025 15:40:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-2/202505031550/1/A/AO/4/18',
#   'course': 'Paradise Pointe Golf Course - The Posse',
#   'lat': 39.4230916,
#   'lon': -94.5472098,
#   'players': 4,
#   'price': 64.0,
#   'tee_time': 'Sat, 03 May 2025 15:50:00 GMT'},
#  {'book_url': 'https://bookateetime.teequest.com/teetime/24-2/202505031600/1/A/AO/4/18',
#   'course': 'Paradise Pointe Golf Course - The Posse',
#   'lat': 39.4230916,
#   'lon': -94.5472098,
#   'players': 4,
#   'price': 64.0,
#   'tee_time': 'Sat, 03 May 2025 16:00:00 GMT'},
#  {'book_url': 'https://golfback.com/#/course/398d44ce-a908-4ce7-8f50-e5f4bdc77b73/date/2025-05-03/teetime
00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/12159#/teetimes',
#   'course': 'Heritage Park Golf Course',
#   'lat': 38.8273693,
#   'lon': -94.7550834,
#   'players': 4,
#   'price': 36.0,
#   'tee_time': 'Sat, 03 May 2025 17:06:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/12159#/teetimes',
#   'course': 'Heritage Park Golf Course',
#   'lat': 38.8273693,
#   'lon': -94.7550834,
#   'players': 4,
#   'price': 36.0,
#   'tee_time': 'Sat, 03 May 2025 17:15:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/12159#/teetimes',
#   'course': 'Heritage Park Golf Course',
#   'lat': 38.8273693,
#   'lon': -94.7550834,
#   'players': 4,
#   'price': 36.0,
#   'tee_time': 'Sat, 03 May 2025 17:24:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/12159#/teetimes',
#   'course': 'Heritage Park Golf Course',
#   'lat': 38.8273693,
#   'lon': -94.7550834,
#   'players': 4,
#   'price': 36.0,
#   'tee_time': 'Sat, 03 May 2025 17:33:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/12159#/teetimes',
#   'course': 'Heritage Park Golf Course',
#   'lat': 38.8273693,
#   'lon': -94.7550834,
#   'players': 4,
#   'price': 36.0,
#   'tee_time': 'Sat, 03 May 2025 17:42:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/11026#/teetimes',
#   'course': 'Tomahawk Hills Golf Course',
#   'lat': 38.9971895,
#   'lon': -94.7900334,
#   'players': 4,
#   'price': 33.0,
#   'tee_time': 'Sat, 03 May 2025 16:20:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/11026#/teetimes',
#   'course': 'Tomahawk Hills Golf Course',
#   'lat': 38.9971895,
#   'lon': -94.7900334,
#   'players': 4,
#   'price': 33.0,
#   'tee_time': 'Sat, 03 May 2025 16:30:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/11026#/teetimes',
#   'course': 'Tomahawk Hills Golf Course',
#   'lat': 38.9971895,
#   'lon': -94.7900334,
#   'players': 4,
#   'price': 33.0,
#   'tee_time': 'Sat, 03 May 2025 16:40:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/11026#/teetimes',
#   'course': 'Tomahawk Hills Golf Course',
#   'lat': 38.9971895,
#   'lon': -94.7900334,
#   'players': 4,
#   'price': 33.0,
#   'tee_time': 'Sat, 03 May 2025 16:50:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/11026#/teetimes',
#   'course': 'Tomahawk Hills Golf Course',
#   'lat': 38.9971895,
#   'lon': -94.7900334,
#   'players': 4,
#   'price': 33.0,
#   'tee_time': 'Sat, 03 May 2025 17:00:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/11026#/teetimes',
#   'course': 'Tomahawk Hills Golf Course',
#   'lat': 38.9971895,
#   'lon': -94.7900334,
#   'players': 4,
#   'price': 33.0,
#   'tee_time': 'Sat, 03 May 2025 17:10:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/11026#/teetimes',
#   'course': 'Tomahawk Hills Golf Course',
#   'lat': 38.9971895,
#   'lon': -94.7900334,
#   'players': 4,
#   'price': 33.0,
#   'tee_time': 'Sat, 03 May 2025 17:20:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/11026#/teetimes',
#   'course': 'Tomahawk Hills Golf Course',
#   'lat': 38.9971895,
#   'lon': -94.7900334,
#   'players': 4,
#   'price': 33.0,
#   'tee_time': 'Sat, 03 May 2025 17:30:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/11026#/teetimes',
#   'course': 'Tomahawk Hills Golf Course',
#   'lat': 38.9971895,
#   'lon': -94.7900334,
#   'players': 4,
#   'price': 33.0,
#   'tee_time': 'Sat, 03 May 2025 17:40:00 GMT'},
#  {'book_url': 'https://foreupsoftware.com/index.php/booking/22857/11026#/teetimes',
#   'course': 'Tomahawk Hills Golf Course',
#   'lat': 38.9971895,
#   'lon': -94.7900334,
#   'players': 4,
#   'price': 33.0,
#   'tee_time': 'Sat, 03 May 2025 17:50:00 GMT'}]

# %% [markdown]
# ## Weather Stuff

# %%
import requests
from datetime import datetime, timedelta

# Coordinates
lat = 39.2528261
lon = -94.4788154

# Get metadata from NOAA
point_url = f"https://api.weather.gov/points/{lat},{lon}"
headers = {
    "User-Agent": "my-weather-app (your@email.com)"
}

try:
  point_response = requests.get(point_url, headers=headers, timeout=10)
  point_response.raise_for_status()
  forecast_url = point_response.json()["properties"]["forecastHourly"]
except Exception as e:
  raise RuntimeError(f"Failed to get forecast URL from NOAA: {e}")

# Get forecast
try:
  forecast_response = requests.get(forecast_url, headers=headers, timeout=10)
  forecast_response.raise_for_status()
  forecast_periods = forecast_response.json()["properties"]["periods"]
except Exception as e:
  raise RuntimeError(f"Failed to fetch forecast: {e}")

# Get next Sunday
today = datetime.today()
days_ahead = (6 - today.weekday()) % 7  # 6 = Sunday
sunday = (today + timedelta(days=days_ahead)).strftime("%A")

# Find Sunday in forecast
sunday_forecast = next((p for p in forecast_periods if p["name"] == sunday), None)

if sunday_forecast:
  print(f"Forecast for Sunday at {lat}, {lon}:")
  print(f"{sunday_forecast['name']}: {sunday_forecast['detailedForecast']}")
else:
  print("Sunday forecast not found in NOAA response.")
# Out:
# Sunday forecast not found in NOAA response.

# %%
point_response.json()
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    's': 'https://schema.org/',
#    'geo': 'http://www.opengis.net/ont/geosparql#',
#    'unit': 'http://codes.wmo.int/common/unit/',
#    '@vocab': 'https://api.weather.gov/ontology#',
#    'geometry': {'@id': 's:GeoCoordinates', '@type': 'geo:wktLiteral'},
#    'city': 's:addressLocality',
#    'state': 's:addressRegion',
#    'distance': {'@id': 's:Distance', '@type': 's:QuantitativeValue'},
#    'bearing': {'@type': 's:QuantitativeValue'},
#    'value': {'@id': 's:value'},
#    'unitCode': {'@id': 's:unitCode', '@type': '@id'},
#    'forecastOffice': {'@type': '@id'},
#    'forecastGridData': {'@type': '@id'},
#    'publicZone': {'@type': '@id'},
#    'county': {'@type': '@id'}}],
#  'id': 'https://api.weather.gov/points/39.2528,-94.4788',
#  'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-94.4788, 39.2528]},
#  'properties': {'@id': 'https://api.weather.gov/points/39.2528,-94.4788',
#   '@type': 'wx:Point',
#   'cwa': 'EAX',
#   'forecastOffice': 'https://api.weather.gov/offices/EAX',
#   'gridId': 'EAX',
#   'gridX': 47,
#   'gridY': 58,
#   'forecast': 'https://api.weather.gov/gridpoints/EAX/47,58/forecast',
#   'forecastHourly': 'https://api.weather.gov/gridpoints/EAX/47,58/forecast/hourly',
#   'forecastGridData': 'https://api.weather.gov/gridpoints/EAX/47,58',
#   'observationStations': 'https://api.weather.gov/gridpoints/EAX/47,58/stations',
#   'relativeLocation': {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.480994, 39.21727]},
#    'properties': {'city': 'Pleasant Valley',
#     'state': 'MO',
#     'distance': {'unitCode': 'wmoUnit:m', 'value': 3955.2777327098},
#     'bearing': {'unitCode': 'wmoUnit:degree_(angle)', 'value': 2}}},
#   'forecastZone': 'https://api.weather.gov/zones/forecast/MOZ029',
#   'county': 'https://api.weather.gov/zones/county/MOC047',
#   'fireWeatherZone': 'https://api.weather.gov/zones/fire/MOZ029',
#   'timeZone': 'America/Chicago',
#   'radarStation': 'KEAX'}}

# %%
forecast_response.json()['properties']['periods']
# Out:
# [{'number': 1,
#   'name': '',
#   'startTime': '2025-05-02T07:00:00-05:00',
#   'endTime': '2025-05-02T08:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 54,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 9.444444444444445},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 83},
#   'windSpeed': '5 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 2,
#   'name': '',
#   'startTime': '2025-05-02T08:00:00-05:00',
#   'endTime': '2025-05-02T09:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 16},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#   'windSpeed': '6 mph',
#   'windDirection': 'WSW',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,20?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 3,
#   'name': '',
#   'startTime': '2025-05-02T09:00:00-05:00',
#   'endTime': '2025-05-02T10:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 21},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#   'windSpeed': '7 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,20?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 4,
#   'name': '',
#   'startTime': '2025-05-02T10:00:00-05:00',
#   'endTime': '2025-05-02T11:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 60,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 27},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 72},
#   'windSpeed': '8 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 5,
#   'name': '',
#   'startTime': '2025-05-02T11:00:00-05:00',
#   'endTime': '2025-05-02T12:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 29},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#   'windSpeed': '8 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 6,
#   'name': '',
#   'startTime': '2025-05-02T12:00:00-05:00',
#   'endTime': '2025-05-02T13:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 31},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 70},
#   'windSpeed': '9 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 7,
#   'name': '',
#   'startTime': '2025-05-02T13:00:00-05:00',
#   'endTime': '2025-05-02T14:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 29},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 65},
#   'windSpeed': '9 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 8,
#   'name': '',
#   'startTime': '2025-05-02T14:00:00-05:00',
#   'endTime': '2025-05-02T15:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 27},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 10},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 62},
#   'windSpeed': '10 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 9,
#   'name': '',
#   'startTime': '2025-05-02T15:00:00-05:00',
#   'endTime': '2025-05-02T16:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 64,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 30},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 9.444444444444445},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 58},
#   'windSpeed': '10 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 10,
#   'name': '',
#   'startTime': '2025-05-02T16:00:00-05:00',
#   'endTime': '2025-05-02T17:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 64,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 33},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 8.88888888888889},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 56},
#   'windSpeed': '12 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 11,
#   'name': '',
#   'startTime': '2025-05-02T17:00:00-05:00',
#   'endTime': '2025-05-02T18:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 30},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 8.88888888888889},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 60},
#   'windSpeed': '13 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 12,
#   'name': '',
#   'startTime': '2025-05-02T18:00:00-05:00',
#   'endTime': '2025-05-02T19:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 28},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 8.333333333333334},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 60},
#   'windSpeed': '12 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 13,
#   'name': '',
#   'startTime': '2025-05-02T19:00:00-05:00',
#   'endTime': '2025-05-02T20:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 20},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.777777777777778},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 62},
#   'windSpeed': '12 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers,20?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 14,
#   'name': '',
#   'startTime': '2025-05-02T20:00:00-05:00',
#   'endTime': '2025-05-02T21:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 57,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 12},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.777777777777778},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#   'windSpeed': '10 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 15,
#   'name': '',
#   'startTime': '2025-05-02T21:00:00-05:00',
#   'endTime': '2025-05-02T22:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.777777777777778},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 72},
#   'windSpeed': '8 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 16,
#   'name': '',
#   'startTime': '2025-05-02T22:00:00-05:00',
#   'endTime': '2025-05-02T23:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 54,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 8},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.222222222222222},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 71},
#   'windSpeed': '7 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 17,
#   'name': '',
#   'startTime': '2025-05-02T23:00:00-05:00',
#   'endTime': '2025-05-03T00:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 52,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 7},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.222222222222222},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 77},
#   'windSpeed': '6 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 18,
#   'name': '',
#   'startTime': '2025-05-03T00:00:00-05:00',
#   'endTime': '2025-05-03T01:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 51,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 6},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.222222222222222},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#   'windSpeed': '6 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 19,
#   'name': '',
#   'startTime': '2025-05-03T01:00:00-05:00',
#   'endTime': '2025-05-03T02:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 50,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 5},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.222222222222222},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 83},
#   'windSpeed': '6 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 20,
#   'name': '',
#   'startTime': '2025-05-03T02:00:00-05:00',
#   'endTime': '2025-05-03T03:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 49,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 83},
#   'windSpeed': '7 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 21,
#   'name': '',
#   'startTime': '2025-05-03T03:00:00-05:00',
#   'endTime': '2025-05-03T04:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#   'windSpeed': '7 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 22,
#   'name': '',
#   'startTime': '2025-05-03T04:00:00-05:00',
#   'endTime': '2025-05-03T05:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 47,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 3},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#   'windSpeed': '7 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 23,
#   'name': '',
#   'startTime': '2025-05-03T05:00:00-05:00',
#   'endTime': '2025-05-03T06:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 46,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 2},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#   'windSpeed': '6 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 24,
#   'name': '',
#   'startTime': '2025-05-03T06:00:00-05:00',
#   'endTime': '2025-05-03T07:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 45,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#   'windSpeed': '7 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 25,
#   'name': '',
#   'startTime': '2025-05-03T07:00:00-05:00',
#   'endTime': '2025-05-03T08:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 45,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#   'windSpeed': '7 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 26,
#   'name': '',
#   'startTime': '2025-05-03T08:00:00-05:00',
#   'endTime': '2025-05-03T09:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 47,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 83},
#   'windSpeed': '8 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 27,
#   'name': '',
#   'startTime': '2025-05-03T09:00:00-05:00',
#   'endTime': '2025-05-03T10:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 51,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 74},
#   'windSpeed': '8 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 28,
#   'name': '',
#   'startTime': '2025-05-03T10:00:00-05:00',
#   'endTime': '2025-05-03T11:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 53,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 69},
#   'windSpeed': '10 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 29,
#   'name': '',
#   'startTime': '2025-05-03T11:00:00-05:00',
#   'endTime': '2025-05-03T12:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 62},
#   'windSpeed': '10 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 30,
#   'name': '',
#   'startTime': '2025-05-03T12:00:00-05:00',
#   'endTime': '2025-05-03T13:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 57,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 10},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 57},
#   'windSpeed': '12 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 31,
#   'name': '',
#   'startTime': '2025-05-03T13:00:00-05:00',
#   'endTime': '2025-05-03T14:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 60,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 8},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value':
06:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 47,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 82},
#   'windSpeed': '2 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 72,
#   'name': '',
#   'startTime': '2025-05-05T06:00:00-05:00',
#   'endTime': '2025-05-05T07:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 46,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 1},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 82},
#   'windSpeed': '2 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 73,
#   'name': '',
#   'startTime': '2025-05-05T07:00:00-05:00',
#   'endTime': '2025-05-05T08:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 47,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 79},
#   'windSpeed': '2 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 74,
#   'name': '',
#   'startTime': '2025-05-05T08:00:00-05:00',
#   'endTime': '2025-05-05T09:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 50,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5.555555555555555},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 74},
#   'windSpeed': '2 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 75,
#   'name': '',
#   'startTime': '2025-05-05T09:00:00-05:00',
#   'endTime': '2025-05-05T10:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 54,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.111111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 66},
#   'windSpeed': '3 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 76,
#   'name': '',
#   'startTime': '2025-05-05T10:00:00-05:00',
#   'endTime': '2025-05-05T11:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 58,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 60},
#   'windSpeed': '3 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 77,
#   'name': '',
#   'startTime': '2025-05-05T11:00:00-05:00',
#   'endTime': '2025-05-05T12:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 54},
#   'windSpeed': '5 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 78,
#   'name': '',
#   'startTime': '2025-05-05T12:00:00-05:00',
#   'endTime': '2025-05-05T13:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 50},
#   'windSpeed': '5 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 79,
#   'name': '',
#   'startTime': '2025-05-05T13:00:00-05:00',
#   'endTime': '2025-05-05T14:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 65,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 0},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 46},
#   'windSpeed': '6 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 80,
#   'name': '',
#   'startTime': '2025-05-05T14:00:00-05:00',
#   'endTime': '2025-05-05T15:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 66,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
# ...
#   'shortForecast': 'Slight Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 132,
#   'name': '',
#   'startTime': '2025-05-07T18:00:00-05:00',
#   'endTime': '2025-05-07T19:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 69,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 23},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 56},
#   'windSpeed': '9 mph',
#   'windDirection': 'E',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,20?size=small',
#   'shortForecast': 'Slight Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 133,
#   'name': '',
#   'startTime': '2025-05-07T19:00:00-05:00',
#   'endTime': '2025-05-07T20:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 68,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 25},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 57},
#   'windSpeed': '9 mph',
#   'windDirection': 'E',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 134,
#   'name': '',
#   'startTime': '2025-05-07T20:00:00-05:00',
#   'endTime': '2025-05-07T21:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 66,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 25},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 60},
#   'windSpeed': '8 mph',
#   'windDirection': 'E',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 135,
#   'name': '',
#   'startTime': '2025-05-07T21:00:00-05:00',
#   'endTime': '2025-05-07T22:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 64,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 25},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 65},
#   'windSpeed': '8 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 136,
#   'name': '',
#   'startTime': '2025-05-07T22:00:00-05:00',
#   'endTime': '2025-05-07T23:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 25},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 70},
#   'windSpeed': '7 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 137,
#   'name': '',
#   'startTime': '2025-05-07T23:00:00-05:00',
#   'endTime': '2025-05-08T00:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 25},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 73},
#   'windSpeed': '7 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 138,
#   'name': '',
#   'startTime': '2025-05-08T00:00:00-05:00',
#   'endTime': '2025-05-08T01:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 60,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 25},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#   'windSpeed': '6 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 139,
#   'name': '',
#   'startTime': '2025-05-08T01:00:00-05:00',
#   'endTime': '2025-05-08T02:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 30},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 78},
#   'windSpeed': '6 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 140,
#   'name': '',
#   'startTime': '2025-05-08T02:00:00-05:00',
#   'endTime': '2025-05-08T03:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 58,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 30},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#   'windSpeed': '6 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 141,
#   'name': '',
#   'startTime': '2025-05-08T03:00:00-05:00',
#   'endTime': '2025-05-08T04:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 58,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 30},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 82},
#   'windSpeed': '6 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 142,
#   'name': '',
#   'startTime': '2025-05-08T04:00:00-05:00',
#   'endTime': '2025-05-08T05:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 57,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 30},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 83},
#   'windSpeed': '6 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_hi,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 143,
#   'name': '',
#   'startTime': '2025-05-08T05:00:00-05:00',
#   'endTime': '2025-05-08T06:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 30},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 85},
#   'windSpeed': '6 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 144,
#   'name': '',
#   'startTime': '2025-05-08T06:00:00-05:00',
#   'endTime': '2025-05-08T07:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 30},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 87},
#   'windSpeed': '7 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 145,
#   'name': '',
#   'startTime': '2025-05-08T07:00:00-05:00',
#   'endTime': '2025-05-08T08:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 33},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#   'windSpeed': '7 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 146,
#   'name': '',
#   'startTime': '2025-05-08T08:00:00-05:00',
#   'endTime': '2025-05-08T09:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 57,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 33},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 84},
#   'windSpeed': '8 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 147,
#   'name': '',
#   'startTime': '2025-05-08T09:00:00-05:00',
#   'endTime': '2025-05-08T10:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 33},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 80},
#   'windSpeed': '8 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 148,
#   'name': '',
#   'startTime': '2025-05-08T10:00:00-05:00',
#   'endTime': '2025-05-08T11:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 33},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#   'windSpeed': '9 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 149,
#   'name': '',
#   'startTime': '2025-05-08T11:00:00-05:00',
#   'endTime': '2025-05-08T12:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 33},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 70},
#   'windSpeed': '9 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 150,
#   'name': '',
#   'startTime': '2025-05-08T12:00:00-05:00',
#   'endTime': '2025-05-08T13:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 65,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 33},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 65},
#   'windSpeed': '10 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers,30?size=small',
#   'shortForecast': 'Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 151,
#   'name': '',
#   'startTime': '2025-05-08T13:00:00-05:00',
#   'endTime': '2025-05-08T14:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 67,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 41},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 61},
#   'windSpeed': '10 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_sct,40?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 152,
#   'name': '',
#   'startTime': '2025-05-08T14:00:00-05:00',
#   'endTime': '2025-05-08T15:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 68,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 41},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 59},
#   'windSpeed': '10 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_sct,40?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 153,
#   'name': '',
#   'startTime': '2025-05-08T15:00:00-05:00',
#   'endTime': '2025-05-08T16:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 69,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 41},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 57},
#   'windSpeed': '10 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_hi,40?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 154,
#   'name': '',
#   'startTime': '2025-05-08T16:00:00-05:00',
#   'endTime': '2025-05-08T17:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 69,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 41},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 57},
#   'windSpeed': '10 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_hi,40?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 155,
#   'name': '',
#   'startTime': '2025-05-08T17:00:00-05:00',
#   'endTime': '2025-05-08T18:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 69,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 41},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.666666666666666},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 56},
#   'windSpeed': '10 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_hi,40?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 156,
#   'name': '',
#   'startTime': '2025-05-08T18:00:00-05:00',
#   'endTime': '2025-05-08T19:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 69,
#   'temperatureUnit': 'F',
#   'temperatureTrend': '',
#   'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 41},
#   'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 11.11111111111111},
#   'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 55},
#   'windSpeed': '9 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,40?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''}]
