# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
from datetime import datetime
import pytz

# %%
sw_lat, sw_long = 38.757, -94.908
ne_lat, ne_long = 39.427, -94.235
query = f"""
[out:json];
(
  node["leisure"="golf_course"]({sw_lat}, {sw_long}, {ne_lat}, {ne_long});
  way["leisure"="golf_course"]({sw_lat}, {sw_long}, {ne_lat}, {ne_long});
  relation["leisure"="golf_course"]({sw_lat}, {sw_long}, {ne_lat}, {ne_long});
);
out center;
"""

response = requests.post("https://overpass-api.de/api/interpreter", data={"data": query})
data = response.json()
for el in data["elements"]:
  name = el.get("tags", {}).get("name")
  lat = el.get("lat")
  lon = el.get("lon")
  if lat == None:
    lat = el.get("center", {}).get("lat")
  if lon == None:
    lon = el.get("center", {}).get("lon")
  if name != None:
    print(f'{name}: {lat}, {lon}')
  # print(el)
# Out:
# Posse Course: 39.4213658, -94.5476547
# The Hill Course: 38.986333, -94.5238809
# The Rock Course: 38.9893881, -94.5222873
# The River Course: 38.9919431, -94.5278009
# Paradise Pointe: 39.4232906, -94.5514754
# Brough Creek National GC: 39.1671392, -94.7610853
# Smiley's Golf Complex: 38.9440764, -94.8480508
# Overland Park Golf Course: 38.90372, -94.7189616
# Westlinks Golf Course: 38.8926212, -94.7335267
# Swope Memorial Golf Course: 38.9988071, -94.5131265
# Heart of America Golf Course: 38.991176, -94.5260483
# St Andrews Golf Club: 38.8787932, -94.7118029
# Lake Quivira Country Club: 39.0455078, -94.7657634
# Milburn Country Club: 39.0040805, -94.6767136
# Tomahawk Hills Golf Course: 38.9971895, -94.7900334
# Royal Meadows Golf Club: 39.0336354, -94.4583346
# The Kansas City Country Club: 39.0215514, -94.6208824
# Sycamore Ridge Golf Club: 38.7565789, -94.840674
# Wolf Creek Golf: 38.7927887, -94.7537362
# Driving Range: 39.2654783, -94.5128536
# Hodge Park Golf Course: 39.2532934, -94.4939931
# Shoal Creek Golf Course: 39.2528261, -94.4788154
# Leavenworth Golf Club (CLOSED): 39.2644117, -94.9046453
# Ironhorse Golf Club: 38.8509525, -94.6350275
# Heritage Park Golf Course: 38.8273693, -94.7550834
# Cardinal Hill Golf Course: 39.262035, -94.4071598
# Paradise Point Golf Course: 39.4256056, -94.5464477
# Hillcrest Golf & Country Club: 38.9802582, -94.5252091
# Indian Hills Country Club: 39.0029916, -94.6230982
# Mission Hills Country Club: 39.0291282, -94.6120171
# Blue Hills Country Club: 38.8979281, -94.5993411
# Eagles' Landing Golf Course: 38.8357479, -94.5514032
# Oakwood Country Club: 38.9442973, -94.5532728
# Minor Park Golf Course: 38.9218788, -94.5789712
# Drumm Farm Golf Club: 39.0620829, -94.3981964
# Sunflower Hills Golf Course: 39.1037935, -94.8676643
# Winterstone Golf Course: 39.1250818, -94.3787228
# Shiloh Springs Golf Course: 39.3617378, -94.7280011
# Adams Pointe Golf Course: 39.019879, -94.2414334
# MariMack Golf Complex: 39.371535, -94.3503011
# Falcon Lakes Golf Club: 39.1650906, -94.9107302
# Dub's Dread Golf Club: 39.1685497, -94.8752899
# Teetering Rocks Golf Course: 38.9628262, -94.4396519
# Fred Arbanas Golf Course: 38.9186516, -94.456896
# Par 3 course: 38.9222203, -94.4539399
# The Unity Village Golf Course: 38.9536138, -94.4054117
# Lake of the Forest Golf Course: 39.0690382, -94.8319121
# Posse: 39.4230916, -94.5472098
# Shamrock Hills Golf Club: 38.8635434, -94.3665596
# Falcon Lakes Golf Club: 39.1650505, -94.910161
# Tiffany Greens Golf Club: 39.2804914, -94.6433335
# Sykes/Lady Overland Park Golf Complex: 38.8981327, -94.7259369
# Staley Farms Golf Club: 39.2818563, -94.5455377
# The Deuce at the National: 39.2057349, -94.6991987
# The Duece at the National: 39.2135906, -94.7021915
# The National Golf Club: 39.2197518, -94.7097866
# Falcon Ridge Golf Course: 38.9542992, -94.8245417
# Creekmoor Golf Club: 38.8334137, -94.4689148
# Grand Summit Golf & Country Club: 38.8500334, -94.5148175
# Country Club of Leawood: 38.8985634, -94.6200496
# Deer Creek Golf Club: 38.8921486, -94.660734
# Nicklaus Golf Club at LionsGate: 38.8752099, -94.6561277
# Lakewood Oaks Golf Club: 39.0063027, -94.3637894
# Stone Canyon Golf Club: 39.0427869, -94.3179918
# Country Club at Loch Lloyd: 38.8349045, -94.5953927
# Country Club Gardens: 39.0346067, -94.2628347
# Painted Hills Golf Club: 39.1242683, -94.7417212
# Shawnee Golf Course & Country Club: 39.0107826, -94.8633368
# Shadow Glen Golf Club: 38.9366702, -94.8948041
# Prairie Highlands Golf Course: 38.8617819, -94.8832094
# Hallbrook Country Club: 38.9220061, -94.6175308
# Canyon Farms Golf Club: 38.9641577, -94.7908632

# %%
class GolfCourse:
  def __init__(self, id, name, lat, lon, source):
    self.id = id
    self.name = name
    self.lat = lat
    self.lon = lon
    self.source = source

  def to_dict(self):
    return {
      "id": self.id,
      "name": self.name,
      "lat": self.lat,
      "lon": self.lon,
      "source": self.source
    }

  def __repr__(self):
    return f"GolfCourse(name={self.name}, lat={self.lat}, lon={self.lon}), source={self.source})"

# %%
# Coordinates you posted — cleaned into a dictionary
coordinates = {
  'Shoal Creek Golf Course': (39.2528261, -94.4788154),
  'Hodge Park Golf Course': (39.2532934, -94.4939931),
  'Winterstone Golf Course': (39.1250818, -94.3787228),
  'Adams Pointe Golf Course': (39.019879, -94.2414334),
  'Heart of America Golf Course': (38.991176, -94.5260483),
  'Sycamore Ridge Golf Club': (38.7565789, -94.840674),
  'Paradise Pointe Golf Course - The Outlaw': (39.4232906, -94.5514754),  # Using Paradise Pointe
  'Paradise Pointe Golf Course - The Posse': (39.4230916, -94.5472098),  # Posse
  'Falcon Lakes Golf Club': (39.1650505, -94.910161),
  "Dub's Dread Golf Club": (39.1685497, -94.8752899),
  'Painted Hills Golf Club': (39.1242683, -94.7417212),
  'Drumm Farm Golf Club - Full': (39.0620829, -94.3981964),
  'Drumm Farm Golf Club - Executive': (39.0620829, -94.3981964),  # Same coords
  'Royal Meadows Golf Club': (39.0336354, -94.4583346),
  'Teetering Rocks Golf Course': (38.9628262, -94.4396519),
  'Heritage Park Golf Course': (38.8273693, -94.7550834),
  'Tomahawk Hills Golf Course': (38.9971895, -94.7900334),
  'Sunflower Hills Golf Course': (39.1037935, -94.8676643),
}

# %%
bookateetime_courses = {
  'Shoal Creek Golf Course': '118-1',
  'Hodge Park Golf Course': '117-1',
  'Winterstone Golf Course': '62-1',
  'Adams Pointe Golf Course': '45-1',
  'Heart of America Golf Course': '49-1',
  'Sycamore Ridge Golf Club': '44-1',
  'Paradise Pointe Golf Course - The Outlaw': '24-1',
  'Paradise Pointe Golf Course - The Posse': '24-2',
}

chronogolf_courses = {
  'Falcon Lakes Golf Club': 6633,
}

golfback_courses = {
  "Dub's Dread Golf Club": '398d44ce-a908-4ce7-8f50-e5f4bdc77b73',
  'Painted Hills Golf Club': '857a12d4-a9cf-4a43-afe2-60940bdc7438',
  'Drumm Farm Golf Club - Full': 'd70999c9-d7d4-4008-9f41-4e9551b3c796',
  'Drumm Farm Golf Club - Executive': '9a1de435-8a46-4840-9cdc-332c3cfea782',
  'Royal Meadows Golf Club': 'd2278228-4700-4354-95a8-422a8f9a5a16'
}

foreup_courses = {
  'Teetering Rocks Golf Course': 7341,
  'Heritage Park Golf Course': 12159,
  'Tomahawk Hills Golf Course': 11026,
}

loners = {
  'Sunflower Hills Golf Course': 'https://www.sunflowerhillsgolfcourse.com/TeeTimes',
}

# %%
courses = []

# Helper to add courses
def add_courses(source_name, courses_dict):
  for name, id in courses_dict.items():
    coord = coordinates.get(name)
    if coord:
      lat, lon = coord
      courses.append(GolfCourse(id=id, name=name, lat=lat, lon=lon, source=source_name))
    else:
      print(f"[Warning] No coordinates found for: {name}")

add_courses('bookateetime', bookateetime_courses)
add_courses('chronogolf', chronogolf_courses)
add_courses('golfback', golfback_courses)
add_courses('foreup', foreup_courses)
add_courses('loner', loners)

# %%
for course in courses:
  print(course)
# Out:
# GolfCourse(name=Shoal Creek Golf Course, lat=39.2528261, lon=-94.4788154), source=bookateetime)
# GolfCourse(name=Hodge Park Golf Course, lat=39.2532934, lon=-94.4939931), source=bookateetime)
# GolfCourse(name=Winterstone Golf Course, lat=39.1250818, lon=-94.3787228), source=bookateetime)
# GolfCourse(name=Adams Pointe Golf Course, lat=39.019879, lon=-94.2414334), source=bookateetime)
# GolfCourse(name=Heart of America Golf Course, lat=38.991176, lon=-94.5260483), source=bookateetime)
# GolfCourse(name=Sycamore Ridge Golf Club, lat=38.7565789, lon=-94.840674), source=bookateetime)
# GolfCourse(name=Paradise Pointe Golf Course - The Outlaw, lat=39.4232906, lon=-94.5514754), source=bookateetime)
# GolfCourse(name=Paradise Pointe Golf Course - The Posse, lat=39.4230916, lon=-94.5472098), source=bookateetime)
# GolfCourse(name=Falcon Lakes Golf Club, lat=39.1650505, lon=-94.910161), source=chronogolf)
# GolfCourse(name=Dub's Dread Golf Club, lat=39.1685497, lon=-94.8752899), source=golfback)
# GolfCourse(name=Painted Hills Golf Club, lat=39.1242683, lon=-94.7417212), source=golfback)
# GolfCourse(name=Drumm Farm Golf Club - Full, lat=39.0620829, lon=-94.3981964), source=golfback)
# GolfCourse(name=Drumm Farm Golf Club - Executive, lat=39.0620829, lon=-94.3981964), source=golfback)
# GolfCourse(name=Royal Meadows Golf Club, lat=39.0336354, lon=-94.4583346), source=golfback)
# GolfCourse(name=Teetering Rocks Golf Course, lat=38.9628262, lon=-94.4396519), source=foreup)
# GolfCourse(name=Heritage Park Golf Course, lat=38.8273693, lon=-94.7550834), source=foreup)
# GolfCourse(name=Tomahawk Hills Golf Course, lat=38.9971895, lon=-94.7900334), source=foreup)
# GolfCourse(name=Sunflower Hills Golf Course, lat=39.1037935, lon=-94.8676643), source=loner)

# %%
courses[-3].id
# Out:
# 12159

# %%
import json

# Convert to list of dicts
courses_json = [course.to_dict() for course in courses]

# Option 1: Write to local file
with open('../golf_courses.json', 'w') as f:
    json.dump(courses_json, f, indent=2)

print("Saved to golf_courses.json ✅")
# Out:
# Saved to golf_courses.json ✅

# %%
with open('../golf_courses.json', 'r') as f:
  courses_data = json.load(f)

courses = [GolfCourse(**course) for course in courses_data]

# %%
date = '2025-05-02'
players = 4

tee_times_df = pd.DataFrame()

for course in courses:
  if course.source == 'bookateetime':
    # Make a GET request to the URL with the course name and date
    response = requests.get(f"https://bookateetime.teequest.com/search/{course.id}/{date}?selectedPlayers={players}&selectedHoles=18")

    # Decode the response content as a string
    content_str = response.content.decode('utf-8')
    soup = BeautifulSoup(content_str, 'html.parser')
    tee_times = []

    for tee_time_div in soup.find_all('div', class_='tee-time'):
      href = tee_time_div.find('a', class_='btn')['href']
      tt = {
        'course': course.name,
        'tee_time': pd.to_datetime(tee_time_div['data-date-time'], format='%Y%m%d%H%M'), #tee_time_div['data-date-time'],
        'price': float(tee_time_div['data-price']),
        'players': int(tee_time_div['data-available']),
        'lat': course.lat,
        'lon': course.lon,
        'book_url': f'https://bookateetime.teequest.com{href}'
      }
      tee_times.append(tt)

    tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)

  if course.source == 'golfback':
    url = f"https://api.golfback.com/api/v1/courses/{course.id}/date/{date}/teetimes"
    headers = {
      "User-Agent": "Mozilla/5.0",
      "Referer": "https://golfback.com/",
      "Content-Type": "application/json",
    }
    params = {
      "date": date,
      "course_id": course.id,
      "players": players
    }

    response = requests.post(url, headers=headers, json=params)
    tee_times_raw = response.json()['data']
    
    tee_times = []
    for tee_time in tee_times_raw:
      tt = {
        'course': course.name,
        'tee_time': pd.to_datetime(tee_time['dateTime'], format='%Y-%m-%dT%H:%M:%S%z') \
          .astimezone(pytz.timezone("US/Central")).strftime("%Y-%m-%d %H:%M:%S"),
        'price': float(tee_time['rates'][0]['price']),
        'players': tee_time['playersMax'],
        'lat': course.lat,
        'lon': course.lon,
        'book_url': f'https://golfback.com/#/course/{course.id}/date/{date}/teetime/{tee_time['id']}?rateId={tee_time['rates'][0]['ratePlanId']}&holes=18&players={players}'
      }
      tee_times.append(tt)

    tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)
  
  if course.source == 'foreup':
    flip_date = datetime.strptime(date, '%Y-%m-%d').strftime('%m-%d-%Y')
    url = f"https://foreupsoftware.com/index.php/api/booking/times?time=all&date={flip_date}&holes=all&players={players}&booking_class=14824&schedule_id={course.id}&api_key=no_limits"
    headers = {
      "User-Agent": "Mozilla/5.0",
      "Referer": f"https://foreupsoftware.com/index.php/booking/22857/7340",
      "Content-Type": "application/json",
    }
    params = {
      "date": datetime.strptime(date, '%Y-%m-%d').strftime('%m-%d-%Y'),
      "players": players,
    }

    response = requests.get(url, headers=headers, json=params)
    tee_times_raw = response.json()

    tee_times = []
    for tee_time in tee_times_raw:
      # print(tee_time)
      # break
      tt = {
        'course': course.name,
        'tee_time': pd.to_datetime(tee_time['time'], format='%Y-%m-%d %H:%M'),
        'price': float(tee_time['green_fee'] + tee_time['cart_fee']),
        'players': tee_time['available_spots'],
        'lat': course.lat,
        'lon': course.lon,
        'book_url': f'https://foreupsoftware.com/index.php/booking/22857/{course.id}#/teetimes'
      }
      tee_times.append(tt)

    tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)

# %%
tee_times_df
# Out:
#                          course             tee_time  price  players  \
# 0       Shoal Creek Golf Course  2025-05-02 16:20:00   50.0        4
# 1       Shoal Creek Golf Course  2025-05-02 16:30:00   50.0        4
# 2       Shoal Creek Golf Course  2025-05-02 16:40:00   50.0        4
# 3       Shoal Creek Golf Course  2025-05-02 16:50:00   50.0        4
# 4       Shoal Creek Golf Course  2025-05-02 17:00:00   50.0        4
# ..                          ...                  ...    ...      ...
# 430   Heritage Park Golf Course  2025-05-02 07:30:00   48.0        4
# 431  Tomahawk Hills Golf Course  2025-05-02 16:10:00   31.0        4
# 432  Tomahawk Hills Golf Course  2025-05-02 16:20:00   31.0        4
# 433  Tomahawk Hills Golf Course  2025-05-02 16:40:00   31.0        4
# 434  Tomahawk Hills Golf Course  2025-05-02 17:20:00   31.0        4
#
#            lat        lon                                           book_url
# 0    39.252826 -94.478815  https://bookateetime.teequest.com/teetime/118-...
# 1    39.252826 -94.478815  https://bookateetime.teequest.com/teetime/118-...
# 2    39.252826 -94.478815  https://bookateetime.teequest.com/teetime/118-...
# 3    39.252826 -94.478815  https://bookateetime.teequest.com/teetime/118-...
# 4    39.252826 -94.478815  https://bookateetime.teequest.com/teetime/118-...
# ..         ...        ...                                                ...
# 430  38.827369 -94.755083                                                NaN
# 431  38.997189 -94.790033                                                NaN
# 432  38.997189 -94.790033                                                NaN
# 433  38.997189 -94.790033                                                NaN
# 434  38.997189 -94.790033                                                NaN
#
# [435 rows x 7 columns]

# %%
date = '2025-05-02'
players = 4

tee_times_df = pd.DataFrame()

for course in bookateetime_courses.items():
  # Make a GET request to the URL with the course name and date
  response = requests.get(f"https://bookateetime.teequest.com/search/{course[1]}/{date}?selectedPlayers={players}&selectedHoles=18")

  # Decode the response content as a string
  content_str = response.content.decode('utf-8')
  soup = BeautifulSoup(content_str, 'html.parser')
  tee_times = []

  for tee_time_div in soup.find_all('div', class_='tee-time'):
    href = tee_time_div.find('a', class_='btn')['href']
    tt = {
      'course': course[0],
      'tee_time': pd.to_datetime(tee_time_div['data-date-time'], format='%Y%m%d%H%M'), #tee_time_div['data-date-time'],
      'price': float(tee_time_div['data-price']),
      'players': int(tee_time_div['data-available']),
      'book_url': f'https://bookateetime.teequest.com{href}'
    }
    tee_times.append(tt)

  tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)

# Convert the 'date_time' column to datetime format
# tee_times_df['tee_time'] = pd.to_datetime(tee_times_df['tee_time'], format='%Y%m%d%H%M')

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.max_colwidth', None) # Show full column content

tee_times_df[
  tee_times_df['course'] == 'Paradise Pointe Golf Course - The Posse'
].sort_values('tee_time').head(10)
# Out:
#                                       course            tee_time  price  \
# 105  Paradise Pointe Golf Course - The Posse 2025-05-02 08:30:00   46.0
# 106  Paradise Pointe Golf Course - The Posse 2025-05-02 12:50:00   61.0
# 107  Paradise Pointe Golf Course - The Posse 2025-05-02 13:20:00   61.0
# 108  Paradise Pointe Golf Course - The Posse 2025-05-02 13:40:00   61.0
# 109  Paradise Pointe Golf Course - The Posse 2025-05-02 13:50:00   61.0
# 110  Paradise Pointe Golf Course - The Posse 2025-05-02 14:00:00   61.0
# 111  Paradise Pointe Golf Course - The Posse 2025-05-02 14:10:00   61.0
# 112  Paradise Pointe Golf Course - The Posse 2025-05-02 14:20:00   61.0
# 113  Paradise Pointe Golf Course - The Posse 2025-05-02 14:30:00   61.0
# 114  Paradise Pointe Golf Course - The Posse 2025-05-02 14:40:00   61.0
#
#      players  \
# 105        4
# 106        4
# 107        4
# 108        4
# 109        4
# 110        4
# 111        4
# 112        4
# 113        4
# 114        4
#
#                                                                     book_url
# 105  https://bookateetime.teequest.com/teetime/24-2/202505020830/1/A/CS/4/18
# 106  https://bookateetime.teequest.com/teetime/24-2/202505021250/1/A/AO/4/18
# 107  https://bookateetime.teequest.com/teetime/24-2/202505021320/1/A/AO/4/18
# 108  https://bookateetime.teequest.com/teetime/24-2/202505021340/1/A/AO/4/18
# 109  https://bookateetime.teequest.com/teetime/24-2/202505021350/1/A/AO/4/18
# 110  https://bookateetime.teequest.com/teetime/24-2/202505021400/1/A/AO/4/18
# 111  https://bookateetime.teequest.com/teetime/24-2/202505021410/1/A/AO/4/18
# 112  https://bookateetime.teequest.com/teetime/24-2/202505021420/1/A/AO/4/18
# 113  https://bookateetime.teequest.com/teetime/24-2/202505021430/1/A/AO/4/18
# 114  https://bookateetime.teequest.com/teetime/24-2/202505021440/1/A/AO/4/18

# %%
for course in golfback_courses.items():
  url = f"https://api.golfback.com/api/v1/courses/{course[1]}/date/{date}/teetimes"
  headers = {
    "User-Agent": "Mozilla/5.0",
    "Referer": "https://golfback.com/",
    "Content-Type": "application/json",
  }
  params = {
    "date": date,
    "course_id": course[1],
    "players": players
  }

  response = requests.post(url, headers=headers, json=params)
  tee_times_raw = response.json()['data']
  
  tee_times = []
  for tee_time in tee_times_raw:
    tt = {
      'course': course[0],
      'tee_time': pd.to_datetime(tee_time['dateTime'], format='%Y-%m-%dT%H:%M:%S%z') \
        .astimezone(pytz.timezone("US/Central")).strftime("%Y-%m-%d %H:%M:%S"),
      'price': float(tee_time['rates'][0]['price']),
      'players': tee_time['playersMax'],
      'book_url': f'https://golfback.com/#/course/{course[1]}/date/{date}/teetime/{tee_time['id']}?rateId={tee_time['rates'][0]['ratePlanId']}&holes=18&players={players}'
    }
    tee_times.append(tt)

  tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)

# %%
for course in foreup_courses.items():
  flip_date = datetime.strptime(date, '%Y-%m-%d').strftime('%m-%d-%Y')
  url = f"https://foreupsoftware.com/index.php/api/booking/times?time=all&date={flip_date}&holes=all&players={players}&booking_class=14824&schedule_id={course[1]}&api_key=no_limits"
  headers = {
    "User-Agent": "Mozilla/5.0",
    "Referer": f"https://foreupsoftware.com/index.php/booking/22857/7340",
    "Content-Type": "application/json",
  }
  params = {
    "date": datetime.strptime(date, '%Y-%m-%d').strftime('%m-%d-%Y'),
    "players": players,
  }

  response = requests.get(url, headers=headers, json=params)
  tee_times_raw = response.json()

  tee_times = []
  for tee_time in tee_times_raw:
    # print(tee_time)
    # break
    tt = {
      'course': course[0],
      'tee_time': pd.to_datetime(tee_time['time'], format='%Y-%m-%d %H:%M'),
      'price': float(tee_time['green_fee'] + tee_time['cart_fee']),
      'players': tee_time['available_spots']
    }
    tee_times.append(tt)

  tee_times_df = pd.concat([tee_times_df, pd.DataFrame(tee_times)], ignore_index=True)

# %%
tee_times_df.head()
# Out:
#                     course             tee_time  price  players  \
# 0  Shoal Creek Golf Course  2025-05-02 16:20:00   50.0        4
# 1  Shoal Creek Golf Course  2025-05-02 16:30:00   50.0        4
# 2  Shoal Creek Golf Course  2025-05-02 16:40:00   50.0        4
# 3  Shoal Creek Golf Course  2025-05-02 16:50:00   50.0        4
# 4  Shoal Creek Golf Course  2025-05-02 17:00:00   50.0        4
#
#                                                                    book_url
# 0  https://bookateetime.teequest.com/teetime/118-1/202505021620/1/A/CS/4/18
# 1  https://bookateetime.teequest.com/teetime/118-1/202505021630/1/A/CS/4/18
# 2  https://bookateetime.teequest.com/teetime/118-1/202505021640/1/A/CS/4/18
# 3  https://bookateetime.teequest.com/teetime/118-1/202505021650/1/A/CS/4/18
# 4  https://bookateetime.teequest.com/teetime/118-1/202505021700/1/A/CS/4/18

# %%
tee_times_df['tee_time'] = pd.to_datetime(tee_times_df['tee_time'], utc=True)

# %%
tee_times_df.head()
# Out:
#                     course                  tee_time  price  players  \
# 0  Shoal Creek Golf Course 2025-05-02 16:20:00+00:00   50.0        4
# 1  Shoal Creek Golf Course 2025-05-02 16:30:00+00:00   50.0        4
# 2  Shoal Creek Golf Course 2025-05-02 16:40:00+00:00   50.0        4
# 3  Shoal Creek Golf Course 2025-05-02 16:50:00+00:00   50.0        4
# 4  Shoal Creek Golf Course 2025-05-02 17:00:00+00:00   50.0        4
#
#                                                                    book_url
# 0  https://bookateetime.teequest.com/teetime/118-1/202505021620/1/A/CS/4/18
# 1  https://bookateetime.teequest.com/teetime/118-1/202505021630/1/A/CS/4/18
# 2  https://bookateetime.teequest.com/teetime/118-1/202505021640/1/A/CS/4/18
# 3  https://bookateetime.teequest.com/teetime/118-1/202505021650/1/A/CS/4/18
# 4  https://bookateetime.teequest.com/teetime/118-1/202505021700/1/A/CS/4/18

# %%
tee_times_df[
  (tee_times_df['tee_time'].dt.hour >= 16) &
  (tee_times_df['price'] <= 90)
].sort_values(by=['course', 'tee_time']).head()#.to_csv('tee_times.csv', index=False)
# Out:
#                       course                  tee_time  price  players  \
# 68  Adams Pointe Golf Course 2025-05-02 16:09:00+00:00   45.0        4
# 69  Adams Pointe Golf Course 2025-05-02 16:18:00+00:00   45.0        4
# 70  Adams Pointe Golf Course 2025-05-02 16:27:00+00:00   45.0        4
# 71  Adams Pointe Golf Course 2025-05-02 16:36:00+00:00   45.0        4
# 72  Adams Pointe Golf Course 2025-05-02 16:45:00+00:00   45.0        4
#
#                                                                    book_url
# 68  https://bookateetime.teequest.com/teetime/45-1/202505021609/1/A/AO/4/18
# 69  https://bookateetime.teequest.com/teetime/45-1/202505021618/1/A/AO/4/18
# 70  https://bookateetime.teequest.com/teetime/45-1/202505021627/1/A/AO/4/18
# 71  https://bookateetime.teequest.com/teetime/45-1/202505021636/1/A/AO/4/18
# 72  https://bookateetime.teequest.com/teetime/45-1/202505021645/1/A/AO/4/18

# %%
tee_times_df.sort_values(by=['course', 'tee_time']).to_csv('tee_times.csv', index=False)

# %%
response = requests.get('https://tee-time-service-1091750267004.us-central1.run.app/tee_times?date=2025-05-02&players=4')

# %%
response.json()
# Out:
# [{'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021620'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021630'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021640'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021650'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021700'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021710'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021720'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021730'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021740'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021750'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021800'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021810'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021820'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021830'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021840'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021850'},
#  {'course': 'Shoal Creek Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021900'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021254'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021303'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 35.0,
#   'tee_time': '202505021451'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 35.0,
#   'tee_time': '202505021500'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 35.0,
#   'tee_time': '202505021518'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 35.0,
#   'tee_time': '202505021554'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 42.0,
#   'tee_time': '202505021621'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 42.0,
#   'tee_time': '202505021630'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 42.0,
#   'tee_time': '202505021657'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 42.0,
#   'tee_time': '202505021706'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 42.0,
#   'tee_time': '202505021733'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 42.0,
#   'tee_time': '202505021742'},
#  {'course': 'Hodge Park Golf Course',
#   'players': 4,
#   'price': 42.0,
#   'tee_time': '202505021800'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 68.0,
#   'tee_time': '202505020815'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 73.0,
#   'tee_time': '202505020833'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 73.0,
#   'tee_time': '202505020927'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 73.0,
#   'tee_time': '202505021115'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 73.0,
#   'tee_time': '202505021124'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 73.0,
#   'tee_time': '202505021133'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 73.0,
#   'tee_time': '202505021142'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 63.0,
#   'tee_time': '202505021303'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021442'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '202505021451'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '202505021536'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021603'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '202505021612'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '202505021621'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '202505021630'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '202505021639'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '202505021648'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '202505021657'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021706'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021715'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021724'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021733'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021742'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021751'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021800'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021809'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021818'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021827'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021836'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021845'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021854'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021903'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021912'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021921'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021930'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021939'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021948'},
#  {'course': 'Winterstone Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021957'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021609'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021618'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021627'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021636'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021645'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 45.0,
#   'tee_time': '202505021654'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021703'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021712'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021721'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021730'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021739'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021748'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021757'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021806'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021815'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021824'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021833'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021842'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021851'},
#  {'course': 'Adams Pointe Golf Course',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '202505021900'},
#  {'course': 'Sycamore Ridge Golf Club',
#   'players': 4,
#   'price': 59.0,
#   'tee_time': '202505021650'},
#  {'course': 'Sycamore Ridge Golf Club',
#   'players': 4,
#   'price': 59.0,
#   'tee_time': '202505021700'},
#  {'course': 'Sycamore Ridge Golf Club',
#   'players': 4,
#   'price': 59.0,
#   'tee_time': '202505021710'},
#  {'course': 'Sycamore Ridge Golf Club',
#   'players': 4,
#   'price': 59.0,
#   'tee_time': '202505021720'},
#  {'course': 'Sycamore Ridge Golf Club',
#   'players': 4,
#   'price': 59.0,
#   'tee_time': '202505021730'},
#  {'course': 'Sycamore Ridge Golf Club',
#   'players': 4,
#   'price': 59.0,
#   'tee_time': '202505021740'},
#  {'course': 'Sycamore Ridge Golf Club',
#   'players': 4,
#   'price': 59.0,
#   'tee_time': '202505021750'},
#  {'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021140'},
#  {'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021350'},
#  {'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021410'},
#  {'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021420'},
#  {'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'players': 4,
#   'price': 46.0,
#   'tee_time': '202505021430'},
#  {'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021440'},
#  {'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021450'},
#  {'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'players': 4,
#   'price': 48.0,
#   'tee_time': '202505021500'},
#  {'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'players': 4,
#   'price': 48.0,
#   'tee_time': '202505021510'},
#  {'course': 'Paradise Pointe Golf Course - The Outlaw',
#   'players': 4,
#   'price': 48.0,
#   'tee_time': '202505021520'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 46.0,
#   'tee_time': '202505020830'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021250'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021320'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021340'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021350'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021400'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021410'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021420'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021430'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021440'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 61.0,
#   'tee_time': '202505021450'},
#  {'course': 'Paradise Pointe Golf Course - The Posse',
#   'players': 4,
#   'price': 48.0,
#   'tee_time': '202505021520'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 07:09:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 07:18:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 07:27:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 07:36:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 2,
#   'price': 52.0,
#   'tee_time': '2025-05-02 08:12:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 2,
#   'price': 52.0,
#   'tee_time': '2025-05-02 08:21:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 1,
#   'price': 48.0,
#   'tee_time': '2025-05-02 10:27:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 1,
#   'price': 48.0,
#   'tee_time': '2025-05-02 10:36:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 2,
#   'price': 48.0,
#   'tee_time': '2025-05-02 10:45:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 2,
#   'price': 48.0,
#   'tee_time': '2025-05-02 10:54:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 1,
#   'price': 44.0,
#   'tee_time': '2025-05-02 11:21:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 44.0,
#   'tee_time': '2025-05-02 11:39:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 44.0,
#   'tee_time': '2025-05-02 11:48:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 2,
#   'price': 44.0,
#   'tee_time': '2025-05-02 11:57:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 2,
#   'price': 40.0,
#   'tee_time': '2025-05-02 12:06:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 1,
#   'price': 40.0,
#   'tee_time': '2025-05-02 12:15:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '2025-05-02 12:24:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 1,
#   'price': 40.0,
#   'tee_time': '2025-05-02 12:33:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '2025-05-02 12:42:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 40.0,
#   'tee_time': '2025-05-02 12:51:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 2,
#   'price': 31.0,
#   'tee_time': '2025-05-02 13:00:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 13:09:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 13:18:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 13:27:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 13:36:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 13:45:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 13:54:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 14:12:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 14:21:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 14:30:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 14:48:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 14:57:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 15:06:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 15:15:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 15:33:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 15:42:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': '2025-05-02 15:51:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 1,
#   'price': 29.0,
#   'tee_time': '2025-05-02 16:00:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 3,
#   'price': 29.0,
#   'tee_time': '2025-05-02 16:09:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 2,
#   'price': 29.0,
#   'tee_time': '2025-05-02 16:18:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': '2025-05-02 16:27:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': '2025-05-02 16:36:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': '2025-05-02 16:54:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': '2025-05-02 17:03:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': '2025-05-02 17:12:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': '2025-05-02 17:21:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': '2025-05-02 17:30:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': '2025-05-02 17:39:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': '2025-05-02 17:48:00'},
#  {'course': 'Painted Hills Golf Club',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': '2025-05-02 17:57:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 1,
#   'price': 65.0,
#   'tee_time': '2025-05-02 07:32:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 1,
#   'price': 65.0,
#   'tee_time': '2025-05-02 07:56:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 2,
#   'price': 65.0,
#   'tee_time': '2025-05-02 08:12:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 2,
#   'price': 65.0,
#   'tee_time': '2025-05-02 08:44:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 1,
#   'price': 65.0,
#   'tee_time': '2025-05-02 09:24:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 2,
#   'price': 65.0,
#   'tee_time': '2025-05-02 09:48:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 2,
#   'price': 58.0,
#   'tee_time': '2025-05-02 10:20:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '2025-05-02 10:44:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '2025-05-02 10:52:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '2025-05-02 11:24:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 2,
#   'price': 58.0,
#   'tee_time': '2025-05-02 11:32:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '2025-05-02 11:40:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '2025-05-02 11:48:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '2025-05-02 12:20:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '2025-05-02 12:28:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 58.0,
#   'tee_time': '2025-05-02 12:44:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 1,
#   'price': 58.0,
#   'tee_time': '2025-05-02 12:52:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 1,
#   'price': 55.0,
#   'tee_time': '2025-05-02 13:00:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 55.0,
#   'tee_time': '2025-05-02 13:08:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 1,
#   'price': 55.0,
#   'tee_time': '2025-05-02 13:16:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 55.0,
#   'tee_time': '2025-05-02 13:56:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '2025-05-02 14:04:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 1,
#   'price': 50.0,
#   'tee_time': '2025-05-02 14:12:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 50.0,
#   'tee_time': '2025-05-02 14:28:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 52.0,
#   'tee_time': '2025-05-02 14:36:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 52.0,
#   'tee_time': '2025-05-02 14:44:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 52.0,
#   'tee_time': '2025-05-02 14:52:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 37.0,
#   'tee_time': '2025-05-02 15:00:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 37.0,
#   'tee_time': '2025-05-02 15:08:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 37.0,
#   'tee_time': '2025-05-02 15:16:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 1,
#   'price': 37.0,
#   'tee_time': '2025-05-02 15:24:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 1,
#   'price': 37.0,
#   'tee_time': '2025-05-02 15:32:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 37.0,
#   'tee_time': '2025-05-02 15:40:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 37.0,
#   'tee_time': '2025-05-02 15:56:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 33.0,
#   'tee_time': '2025-05-02 16:12:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 3,
#   'price': 33.0,
#   'tee_time': '2025-05-02 16:20:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 33.0,
#   'tee_time': '2025-05-02 16:28:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 16:36:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 16:44:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 16:52:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:08:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:16:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:24:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:32:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:40:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:48:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:56:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:04:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:12:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:20:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:28:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:36:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:44:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:52:00'},
#  {'course': 'Drumm Farm Golf Club - Full',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': '2025-05-02 19:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 07:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 07:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 07:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 07:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 07:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 08:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 08:06:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 08:12:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 08:18:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 08:24:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 08:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 08:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 08:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 08:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 08:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 09:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 09:06:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 09:12:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 09:18:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 09:24:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 09:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 09:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 09:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 09:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 09:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 10:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 10:06:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 10:12:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 10:18:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 10:24:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 10:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 10:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 10:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 10:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 10:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 11:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 11:06:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 11:12:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 11:18:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 11:24:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 11:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 11:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 11:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 11:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 11:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 12:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 12:06:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 12:12:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 12:18:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 12:24:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 12:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 12:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 12:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 12:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 12:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 13:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 13:06:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 13:12:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 13:18:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 13:24:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 13:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 13:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 13:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 13:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 13:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 14:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 14:06:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 14:12:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 14:18:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 14:24:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 14:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 14:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 14:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 14:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 14:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 15:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 15:06:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 15:12:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 15:18:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 15:24:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 15:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 15:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 15:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 15:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 15:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 16:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 16:06:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 16:12:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 16:18:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 16:24:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 16:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 16:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 16:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 16:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 24.0,
#   'tee_time': '2025-05-02 16:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 17:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 17:06:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 17:12:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 17:18:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 17:24:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 17:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 17:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 17:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 17:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 17:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 18:00:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 18:06:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 18:12:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 18:18:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 18:24:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 18:30:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 18:36:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 18:42:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 18:48:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 18:54:00'},
#  {'course': 'Drumm Farm Golf Club - Executive',
#   'players': 4,
#   'price': 20.0,
#   'tee_time': '2025-05-02 19:00:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 1,
#   'price': 44.0,
#   'tee_time': '2025-05-02 07:30:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 44.0,
#   'tee_time': '2025-05-02 07:48:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 08:09:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 08:18:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 08:27:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 08:36:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 08:54:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 2,
#   'price': 44.0,
#   'tee_time': '2025-05-02 09:21:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 3,
#   'price': 44.0,
#   'tee_time': '2025-05-02 09:48:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 44.0,
#   'tee_time': '2025-05-02 09:57:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 1,
#   'price': 51.0,
#   'tee_time': '2025-05-02 10:06:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 2,
#   'price': 51.0,
#   'tee_time': '2025-05-02 10:15:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 11:00:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 11:09:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 11:18:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 11:27:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 2,
#   'price': 39.0,
#   'tee_time': '2025-05-02 11:45:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 39.0,
#   'tee_time': '2025-05-02 11:54:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 2,
#   'price': 36.0,
#   'tee_time': '2025-05-02 12:03:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 36.0,
#   'tee_time': '2025-05-02 12:21:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 36.0,
#   'tee_time': '2025-05-02 12:30:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 36.0,
#   'tee_time': '2025-05-02 12:39:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 36.0,
#   'tee_time': '2025-05-02 12:48:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 36.0,
#   'tee_time': '2025-05-02 12:57:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 1,
#   'price': 36.0,
#   'tee_time': '2025-05-02 13:24:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 36.0,
#   'tee_time': '2025-05-02 13:42:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 36.0,
#   'tee_time': '2025-05-02 13:51:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 2,
#   'price': 36.0,
#   'tee_time': '2025-05-02 14:00:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 2,
#   'price': 36.0,
#   'tee_time': '2025-05-02 14:18:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 2,
#   'price': 42.0,
#   'tee_time': '2025-05-02 14:45:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 42.0,
#   'tee_time': '2025-05-02 14:54:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 15:03:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 15:12:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 15:21:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 15:30:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 15:39:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 15:48:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 15:57:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 16:06:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 16:15:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 16:24:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 16:33:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 16:42:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 16:51:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:00:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:09:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:18:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 2,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:27:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:45:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 17:53:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:01:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:09:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:17:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:25:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:33:00'},
#  {'course': 'Royal Meadows Golf Club',
#   'players': 4,
#   'price': 30.0,
#   'tee_time': '2025-05-02 18:41:00'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 08:20:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 08:30:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 08:50:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 09:00:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 09:10:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 09:20:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 09:40:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 09:50:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 10:10:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 10:20:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 10:50:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 11:00:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 11:10:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 11:20:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 11:30:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 11:40:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 11:50:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 12:20:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 12:30:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 12:50:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 13:20:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 13:30:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 13:40:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 38.0,
#   'tee_time': 'Fri, 02 May 2025 13:50:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 14:00:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 14:10:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 14:20:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 14:30:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 14:40:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 14:50:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 15:00:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 15:10:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 15:20:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 15:30:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 15:40:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 15:50:00 GMT'},
#  {'course': 'Teetering Rocks Golf Course',
#   'players': 4,
#   'price': 32.0,
#   'tee_time': 'Fri, 02 May 2025 16:00:00 GMT'},
#  {'course': 'Heritage Park Golf Course',
#   'players': 4,
#   'price': 48.0,
#   'tee_time': 'Fri, 02 May 2025 07:30:00 GMT'},
#  {'course': 'Heritage Park Golf Course',
#   'players': 4,
#   'price': 29.0,
#   'tee_time': 'Fri, 02 May 2025 18:00:00 GMT'},
#  {'course': 'Tomahawk Hills Golf Course',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': 'Fri, 02 May 2025 16:10:00 GMT'},
#  {'course': 'Tomahawk Hills Golf Course',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': 'Fri, 02 May 2025 16:20:00 GMT'},
#  {'course': 'Tomahawk Hills Golf Course',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': 'Fri, 02 May 2025 16:40:00 GMT'},
#  {'course': 'Tomahawk Hills Golf Course',
#   'players': 4,
#   'price': 31.0,
#   'tee_time': 'Fri, 02 May 2025 17:20:00 GMT'}]
